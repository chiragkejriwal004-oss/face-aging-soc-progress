# %% [markdown]
# # Week 4 Learning - Image Preprocessing
#
# Topics Covered:
# - OpenCV
# - PIL
# - Image Loading
# - Resizing
# - Normalization
# - Tensor Conversion

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.random.randint(0,255,(128,128,3),dtype=np.uint8)

print("Image Shape:", image.shape)

plt.imshow(image)
plt.show()
# Out:
# Image Shape: (128, 128, 3)

# %%
from PIL import Image
import numpy as np

image = Image.fromarray(
    np.random.randint(0,255,(128,128,3),dtype=np.uint8)
)

print(image.size)
# Out:
# (128, 128)

# %%
resized = image.resize((64,64))

print("Original Size:", image.size)
print("Resized Size:", resized.size)
# Out:
# Original Size: (128, 128)
# Resized Size: (64, 64)

# %%
plt.imshow(resized)
plt.title("Resized Image")
plt.show()

# %%
img_array = np.array(resized)

normalized = img_array / 255.0

print("Min:", normalized.min())
print("Max:", normalized.max())
# Out:
# Min: 0.11372549019607843
# Max: 0.8823529411764706

# %%
import torch

tensor_image = torch.tensor(
    normalized,
    dtype=torch.float32
)

print(tensor_image.shape)
# Out:
# torch.Size([64, 64, 3])

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor()
])

print(transform)
# Out:
# Compose(
#     Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
# )

# %%
## Summary

Learned:
- Loading images
- Resizing images
- Image normalization
- Converting images to tensors
- TorchVision transforms

These preprocessing techniques are required before training deep learning models on face datasets.
# Out:
#   File "/tmp/ipykernel_3989/1856027339.py", line 3
#     Learned:
#             ^
# SyntaxError: invalid syntax
