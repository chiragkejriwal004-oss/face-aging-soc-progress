# %% [markdown]
# # Week 1 Learning - Deep Learning Basics
#
# Topics Covered:
# - Artificial Intelligence
# - Machine Learning
# - Deep Learning
# - Neural Networks
# - Applications of Deep Learning

# %%
print("Artificial Intelligence -> Broad field")
print("Machine Learning -> Subset of AI")
print("Deep Learning -> Subset of Machine Learning")
# Out:
# Artificial Intelligence -> Broad field
# Machine Learning -> Subset of AI
# Deep Learning -> Subset of Machine Learning

# %%
import numpy as np

inputs = np.array([1, 2, 3])
weights = np.array([0.2, 0.5, 0.8])

output = np.dot(inputs, weights)

print("Neuron Output:", output)
# Out:
# Neuron Output: 3.6000000000000005

# %% [markdown]
# ## Summary
#
# Learned:
# - Difference between AI, ML and DL
# - Basic idea of neural networks
# - Role of data and weights
# - Applications of deep learning in computer vision
